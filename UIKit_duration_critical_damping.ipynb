# %%
import numpy as np
import scipy
from scipy.optimize import curve_fit
import plotly
from plotly import graph_objects as go
import math
from spring_math import *

# %% [markdown]
# ### In this notebook, we try to find omega given duration when the damping ratio is 1 as is done in UIKit API

# %%
# w = duration * omega, a = -1 + v0 * duration
def simplified(w, a):
    return (a - w) * np.exp(-w)

# %%
ws = np.linspace(0, 10, 1000)
go.FigureWidget(go.Scatter(x=ws, y=simplified(ws, 1)))
# Out:
# FigureWidget({
#     'data': [{'type': 'scatter',
#               'uid': '8100c1fd-c469-4a28-ae38-a1398b3fa48c',
#  …

# %%
def turning_point(a):
    return a + 1

def inflection_point(a):
    return a + 2

# %%
def minimum(a):
    return -np.exp(-a -1)

# %%
-np.log(0.001) - 1
# Out:
# 5.907755278982137

# %% [markdown]
# ### If a > 5.907755278982137, the minimum is less than -0.001
